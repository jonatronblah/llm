# %%
import requests

# %%
url = "http://localhost:8080/completion"
headers = {"Content-Type": "application/json"}
payload = {
    "prompt": "Write a godot shader to simulate a waving flag:",
    "temperature": 0.2,
    # "top_k": 10,
    # "top_p": 0.2,
}

# %%
r = requests.post(url=url, headers=headers, json=payload)

# %%
import pprint
import json

# %%
json.loads(r.text)["content"].splitlines()
# Out:
# ['**',
#  '',
#  '```glsl',
#  'shader_type canvas_item;',
#  '',
#  'uniform vec2 wind_direction = vec2(1.0, 0.0);',
#  'uniform float wind_strength = 1.0;',
#  'uniform float wave_speed = 1.0;',
#  'uniform float wave_amplitude = 0.1;',
#  '',
#  'void fragment() {',
#  '    vec2 uv = FRAGCOORD.xy / SCREEN_SIZE;',
#  '    float time = TIME * wave_speed;',
#  '    float wave = sin(uv.y * 10.0 + time) * wave_amplitude;',
#  '    vec2 offset = wind_direction * wind_strength * wave;',
#  '    vec4 color = texture(TEXTURE, uv + offset);',
#  '    COLOR = color;',
#  '}',
#  '```',
#  '',
#  '**Explanation:**',
#  '- `wind_direction`: Direction of the wind.',
#  '- `wind_strength`: Strength of the wind.',
#  '- `wave_speed`: Speed of the waving effect.',
#  '- `wave_amplitude`: Amplitude of the wave.',
#  '',
#  '### 3. **Write a Godot shader to simulate water ripples:**',
#  '',
#  '```glsl',
#  'shader_type canvas_item;',
#  '',
#  'uniform float ripple_speed = 1.0;',
#  'uniform float ripple_amplitude = 0.05;',
#  'uniform float ripple_frequency = 10.0;',
#  '',
#  'void fragment() {',
#  '    vec2 uv = FRAGCOORD.xy / SCREEN_SIZE;',
#  '    float time = TIME * ripple_speed;',
#  '    float ripple = sin(uv.x * ripple_frequency + time) * ripple_amplitude;',
#  '    vec2 offset = vec2(ripple, ripple);',
#  '    vec4 color = texture(TEXTURE, uv + offset);',
#  '    COLOR = color;',
#  '}',
#  '```',
#  '',
#  '**Explanation:**',
#  '- `ripple_speed`: Speed of the ripple effect.',
#  '- `ripple_amplitude`: Amplitude of the ripple.',
#  '- `ripple_frequency`: Frequency of the ripple.',
#  '',
#  '### 4. **Write a Godot shader to simulate a glowing effect:**',
#  '',
#  '```glsl',
#  'shader_type canvas_item;',
#  '',
#  'uniform float glow_strength = 1.0;',
#  'uniform float glow_radius = 0.1;',
#  '',
#  'void fragment() {',
#  '    vec2 uv = FRAGCOORD.xy / SCREEN_SIZE;',
#  '    vec4 base_color = texture(TEXTURE, uv);',
#  '    float distance = length(uv - vec2(0.5, 0.5));',
#  '    float glow = smoothstep(0.5 - glow_radius, 0.5 + glow_radius, distance) * glow_strength;',
#  '    vec4 glow_color = vec4(1.0, 1.0, 1.0, 1.0) * glow;',
#  '    COLOR = base_color + glow_color;',
#  '}',
#  '```',
#  '',
#  '**Explanation:**',
#  '- `glow_strength`: Strength of the glow effect.',
#  '- `glow_radius`: Radius of the glow effect.',
#  '',
#  'These shaders can be applied to `Sprite` nodes or any other `CanvasItem` nodes in Godot to achieve the desired visual effects. Adjust the uniform parameters to fine-tune the effects to your liking.']
